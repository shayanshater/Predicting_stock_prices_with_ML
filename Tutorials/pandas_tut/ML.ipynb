# %%
import pandas as pd

df = pd.read_csv('archive/diamonds.csv',index_col=0)
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
df['cut'].astype('category').cat.codes
# Out:
# 1        2
# 2        3
# 3        1
# 4        3
# 5        1
#         ..
# 53936    2
# 53937    1
# 53938    4
# 53939    3
# 53940    2
# Length: 53940, dtype: int8

# %%
cut_class_dict = {"Fair": 1, "Good": 2, "Very Good": 3, "Premium": 4, "Ideal": 5}
clarity_dict = {"I3": 1, "I2": 2, "I1": 3, "SI2": 4, "SI1": 5, "VS2": 6, "VS1": 7, "VVS2": 8, "VVS1": 9, "IF": 10, "FL": 11}
color_dict = {"J": 1,"I": 2,"H": 3,"G": 4,"F": 5,"E": 6,"D": 7}

df['cut'] = df['cut'].map(cut_class_dict)
df['clarity'] = df['clarity'].map(clarity_dict)
df['color'] = df['color'].map(color_dict)

# %%
import sklearn
from sklearn import svm, preprocessing
import sklearn.utils

df = sklearn.utils.shuffle(df)


X= df.drop('price',axis =1).values
X = preprocessing.scale(X)
y=df['price'].values

test_size = 200

X_train = X[:-test_size]
y_train = y[:-test_size]

X_test= X[-test_size:]
y_test=y[-test_size:]


clf = svm.SVR(kernel='linear')

clf.fit(X_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
clf.score(X_test,y_test)
# Out:
# 0.8716446607722688

# %%
for X,y in zip(X_test,y_test):
    print(f'Model: {clf.predict([X])[0]}, Actual {y}')
# Out:
# Model: 514.0550467851658, Actual 695
# Model: 8095.269805590502, Actual 5460
# Model: 3477.6549987375697, Actual 3201
# Model: 7657.892390357079, Actual 7504
# Model: 4675.830547142834, Actual 4185
# Model: 1178.3344944912528, Actual 1357
# Model: 6824.668813269211, Actual 8774
# Model: 8015.539857433192, Actual 8598
# Model: 2887.6856437099077, Actual 3343
# Model: 8983.23498958083, Actual 14709
# Model: 4202.909663901481, Actual 3579
# Model: 5088.11720459218, Actual 6533
# Model: 551.675382238011, Actual 907
# Model: 5528.517597011285, Actual 6360
# Model: 8507.584578087823, Actual 8283
# Model: 8400.549144018554, Actual 7577
# Model: 4278.141322812366, Actual 4108
# Model: 1491.420450311995, Actual 1115
# Model: 12349.425607036597, Actual 13993
# Model: 5204.09391839096, Actual 6356
# Model: 543.5214479763131, Actual 485
# Model: 924.8268434130528, Actual 779
# Model: 400.0157855563293, Actual 622
# Model: 667.4910827368935, Actual 622
# Model: 2651.102564595267, Actual 2348
# Model: 605.3170404504758, Actual 726
# Model: 11880.50892509202, Actual 11200
# Model: 1526.9293900466482, Actual 1230
# Model: 3457.434999025827, Actual 2938
# Model: 564.1846173463787, Actual 827
# Model: 8546.22601918107, Actual 12466
# Model: 1146.5465996279672, Actual 806
# Model: 579.1493131582911, Actual 571
# Model: 2836.5141714902907, Actual 2753
# Model: 4404.602174315418, Actual 3672
# Model: 4545.3398887026, Actual 4788
# Model: -584.2048322777282, Actual 429
# Model: -306.2956069650686, Actual 449
# Model: 308.7724369454568, Actual 844
# Model: 1100.2689059244071, Actual 1189
# Model: 2038.0366554555007, Actual 1761
# Model: 1150.127305707529, Actual 1132
# Model: 8227.732651691358, Actual 6088
# Model: 1664.4916069436435, Actual 1654
# Model: 4853.733137653488, Actual 5840
# Model: -421.49809988516245, Actual 445
# Model: 2796.9105900221016, Actual 2194
# Model: 5397.440508846106, Actual 6782
# Model: 10310.426078990848, Actual 12012
# Model: 4821.060102364597, Actual 5010
# Model: 3507.4025434415894, Actual 2541
# Model: 246.36648803263552, Actual 515
# Model: 9401.176866409807, Actual 13950
# Model: 2083.7058506249627, Actual 1348
# Model: 735.5742637332255, Actual 898
# Model: 3316.5310167360894, Actual 2936
# Model: 1492.3424033879837, Actual 1423
# Model: 2233.8682641108207, Actual 1989
# Model: 5223.855712509659, Actual 4710
# Model: -655.1105087774031, Actual 371
# Model: 4798.474196963507, Actual 4398
# Model: 1966.1863223837681, Actual 1935
# Model: 1401.549875260253, Actual 1129
# Model: 1092.5393541541093, Actual 853
# Model: 8099.2818076782105, Actual 13406
# Model: -54.99107501106619, Actual 489
# Model: 4842.955231214255, Actual 3544
# Model: 288.6893557116432, Actual 625
# Model: 7055.596317141526, Actual 8449
# Model: 8198.917779988773, Actual 8050
# Model: 11967.633880386316, Actual 16733
# Model: 389.42004672040366, Actual 666
# Model: 6206.052160697394, Actual 10954
# Model: 10622.316981490923, Actual 11037
# Model: 3251.663289355568, Actual 2839
# Model: 5931.540276586351, Actual 8645
# Model: 1168.206295112529, Actual 1143
# Model: 15198.860101205286, Actual 15231
# Model: 3167.25912252687, Actual 3068
# Model: 73.2569713552175, Actual 605
# Model: 14745.283962150024, Actual 16826
# Model: 1166.3220058372085, Actual 827
# Model: 732.9538032850924, Actual 814
# Model: 5143.956867729284, Actual 5179
# Model: 1468.0434505726093, Actual 1410
# Model: 5369.310587486543, Actual 5550
# Model: 619.0021817983557, Actual 758
# Model: 2925.2615649465415, Actual 2368
# Model: 818.5135850189836, Actual 789
# Model: 4880.378143529732, Actual 4118
# Model: 5656.562508708911, Actual 5280
# Model: 1461.7906915583362, Actual 1318
# Model: 4207.696066735441, Actual 4382
# Model: 11498.92159841253, Actual 12182
# Model: 6164.278041892025, Actual 6616
# Model: 973.5303072572751, Actual 1041
# Model: 6422.401309614737, Actual 5569
# Model: 3553.9613940983545, Actual 3352
# Model: 8561.973980806793, Actual 9828
# Model: 286.32700614968144, Actual 802
# Model: 4956.793131470963, Actual 5505
# Model: 10844.341381565631, Actual 17569
# Model: -239.8266566328507, Actual 419
# Model: 186.10317630761847, Actual 603
# Model: 165.44469909094596, Actual 583
# Model: 5359.531375965442, Actual 2850
# Model: 4441.293593718796, Actual 4623
# Model: 6921.673020609009, Actual 9448
# Model: 6120.669906121884, Actual 6130
# Model: 3599.6482969743834, Actual 2068
# Model: 1099.1119692828952, Actual 1074
# Model: 7705.73721188646, Actual 7636
# Model: 7514.963183717358, Actual 7702
# Model: 6906.104000017561, Actual 7222
# Model: 10783.290794144472, Actual 15460
# Model: -325.8411032258873, Actual 417
# Model: 8071.49262082112, Actual 8574
# Model: 2821.999663396359, Actual 2351
# Model: 569.9463581027835, Actual 642
# Model: 540.6023253040553, Actual 972
# Model: 4420.099114257921, Actual 4735
# Model: 10604.905376337847, Actual 17442
# Model: 5444.022577839704, Actual 7574
# Model: 1028.240799758078, Actual 999
# Model: 407.9176600629621, Actual 854
# Model: -723.8805794928603, Actual 506
# Model: 1016.8507015521086, Actual 883
# Model: 1118.4726932356625, Actual 912
# Model: 12331.212449891898, Actual 15097
# Model: 2940.4231201554026, Actual 2233
# Model: 3970.629668903445, Actual 3879
# Model: 8052.809081497079, Actual 7098
# Model: 2970.0428716321994, Actual 2475
# Model: 9675.702452820973, Actual 14022
# Model: 685.9562836131563, Actual 795
# Model: 13813.226451099612, Actual 16558
# Model: 1419.3722280879729, Actual 1369
# Model: 3238.81923260259, Actual 2444
# Model: 708.3805613125564, Actual 828
# Model: 6046.208521566708, Actual 5871
# Model: 4747.398309121728, Actual 4239
# Model: 3981.154631301497, Actual 4082
# Model: 5411.084733224554, Actual 5088
# Model: 13048.619320211463, Actual 7069
# Model: 172.5333652170807, Actual 467
# Model: 5802.805114869683, Actual 6036
# Model: 2297.0013917647852, Actual 1944
# Model: 239.51762557112443, Actual 810
# Model: 6324.064692488262, Actual 5949
# Model: 5244.330920054963, Actual 6613
# Model: 4704.721451791632, Actual 5854
# Model: 5407.107015761387, Actual 7278
# Model: 2909.7771622886266, Actual 2737
# Model: 5048.412031928352, Actual 5759
# Model: 1530.0441170797994, Actual 1166
# Model: 2372.9778070929488, Actual 2083
# Model: -393.7842927496131, Actual 434
# Model: 545.4416159243283, Actual 706
# Model: 711.6687612789128, Actual 871
# Model: 792.9436582119129, Actual 809
# Model: 362.8974926074379, Actual 587
# Model: 814.0202668634311, Actual 696
# Model: 631.3992087437691, Actual 687
# Model: 4590.011767696123, Actual 3739
# Model: 942.6635862054786, Actual 1094
# Model: 1784.5185143949925, Actual 1397
# Model: 751.0024812004581, Actual 1029
# Model: 7001.353061611502, Actual 9581
# Model: 5481.789879323434, Actual 5088
# Model: 2045.6733679953163, Actual 1961
# Model: 1878.212379433907, Actual 1580
# Model: 1864.3085004729928, Actual 1801
# Model: 1363.973244008036, Actual 1088
# Model: 377.1692376646952, Actual 627
# Model: 2916.041735286708, Actual 2537
# Model: 4010.335351485963, Actual 4642
# Model: 980.9716659859209, Actual 1113
# Model: 1901.7762895256349, Actual 2052
# Model: 598.3378308312426, Actual 762
# Model: 1225.8218510778174, Actual 1076
# Model: 3800.5327646455717, Actual 2488
# Model: 1944.1709722796977, Actual 1261
# Model: 3032.1290600604316, Actual 2952
# Model: 6190.364420378639, Actual 9254
# Model: 2749.6325850951007, Actual 2528
# Model: 3388.924384134653, Actual 2761
# Model: 2327.8662386516135, Actual 2063
# Model: 820.9811554173116, Actual 698
# Model: 1076.9849609745988, Actual 840
# Model: 3638.2450549032524, Actual 3326
# Model: 3308.2709394210724, Actual 2858
# Model: 4648.52569775902, Actual 4497
# Model: 254.5710517957973, Actual 614
# Model: 2956.3328878984426, Actual 2560
# Model: 2057.8301758831994, Actual 2054
# Model: 11678.521936840327, Actual 14542
# Model: 2695.307945846306, Actual 2468
# Model: 1854.4416307671966, Actual 1895
# Model: 6302.786524658821, Actual 5916
# Model: 5331.399017818237, Actual 6843

# %%
clf = svm.SVR(kernel='rbf')

clf.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 clf = svm.SVR(kernel='rbf')
# ----> 3 clf.fit(X_train,y_train)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:257, in BaseLibSVM.fit(self, X, y, sample_weight)
#     254     print("[LibSVM]", end="")
#     256 seed = rnd.randint(np.iinfo("i").max)
# --> 257 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     258 # see comment on the other call to np.iinfo in this file
#     260 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:335, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     321 libsvm.set_verbosity_wrap(self.verbose)
#     323 # we don't pass **self.get_params() to allow subclasses to
#     324 # add other parameters to __init__
#     325 (
#     326     self.support_,
#     327     self.support_vectors_,
#     328     self._n_support,
#     329     self.dual_coef_,
#     330     self.intercept_,
#     331     self._probA,
#     332     self._probB,
#     333     self.fit_status_,
#     334     self._num_iter,
# --> 335 ) = libsvm.fit(
#     336     X,
#     337     y,
#     338     svm_type=solver_type,
#     339     sample_weight=sample_weight,
#     340     class_weight=getattr(self, "class_weight_", np.empty(0)),
#     341     kernel=kernel,
#     342     C=self.C,
#     343     nu=self.nu,
#     344     probability=self.probability,
#     345     degree=self.degree,
#     346     shrinking=self.shrinking,
#     347     tol=self.tol,
#     348     cache_size=self.cache_size,
#     349     coef0=self.coef0,
#     350     gamma=self._gamma,
#     351     epsilon=self.epsilon,
#     352     max_iter=self.max_iter,
#     353     random_seed=random_seed,
#     354 )
#     356 self._warn_from_fit_status()
#
# File _libsvm.pyx:263, in sklearn.svm._libsvm.fit()
#
# KeyboardInterrupt:

# %%
clf.score(X_test,y_test)

for X,y in zip(X_test,y_test):
    print(f'Model: {clf.predict([X])[0]}, Actual {y}')
# Out:
# Model: 4818.691629495694, Actual 4630
# Model: 3544.5332478516684, Actual 3779
# Model: 4627.373720368817, Actual 4751
# Model: 2925.1468759369595, Actual 2513
# Model: 699.4075515463451, Actual 710
# Model: 951.7402259420992, Actual 827
# Model: 3170.8909778510847, Actual 2911
# Model: 2857.588971361893, Actual 2375
# Model: 2401.86312053255, Actual 2294
# Model: 3125.8929332188436, Actual 2193
# Model: 2690.9988766392094, Actual 2367
# Model: 5500.565644564689, Actual 16043
# Model: 2301.08605044641, Actual 2298
# Model: 799.8093484666115, Actual 816
# Model: 6909.042013258679, Actual 8911
# Model: 4547.7755170915625, Actual 4478
# Model: 6488.854263397401, Actual 8951
# Model: 4294.385561293102, Actual 4195
# Model: 927.3414934971656, Actual 766
# Model: 4221.379736690541, Actual 3790
# Model: 6308.376232370252, Actual 17065
# Model: 6395.433953859911, Actual 10764
# Model: 2801.3760662261916, Actual 2838
# Model: 916.4128076750094, Actual 1021
# Model: 3476.476314303978, Actual 3345
# Model: 878.5001242814706, Actual 734
# Model: 6416.277570122693, Actual 17068
# Model: 4658.886626448834, Actual 6291
# Model: 1451.9587801376172, Actual 763
# Model: 4718.630970834359, Actual 4958
# Model: 6610.7604251406865, Actual 9176
# Model: 5772.463656463247, Actual 17079
# Model: 2975.7826541394666, Actual 2366
# Model: 5820.146907338656, Actual 9539
# Model: 4074.729836744757, Actual 4817
# Model: 928.351314807408, Actual 1010
# Model: 2009.3297625487864, Actual 1871
# Model: 859.5221710578376, Actual 721
# Model: 5796.380009803289, Actual 5914
# Model: 997.684840196689, Actual 805
# Model: 2371.03374198523, Actual 1133
# Model: 6595.055934518383, Actual 11565
# Model: 833.2682452365193, Actual 391
# Model: 5849.29364917806, Actual 13629
# Model: 4352.69615422816, Actual 5246
# Model: 479.11397972980876, Actual 698
# Model: 5291.596605743256, Actual 5091
# Model: 3449.0278265426923, Actual 3111
# Model: 1454.1962981737624, Actual 1755
# Model: 1828.2624041207443, Actual 1270
# Model: 3408.047598775173, Actual 3864
# Model: 3345.0530484906985, Actual 3079
# Model: 697.8643901956152, Actual 1035
# Model: 1526.8694051387706, Actual 1262
# Model: 4191.237835020569, Actual 5535
# Model: 7436.545680138685, Actual 15584
# Model: 4852.547944023015, Actual 6302
# Model: 4756.626712206011, Actual 6073
# Model: 1587.4322628108087, Actual 1567
# Model: 4628.752512156275, Actual 5189
# Model: 1092.3230347255057, Actual 670
# Model: 526.5108767303823, Actual 555
# Model: 5400.983989648501, Actual 7805
# Model: 1252.9930172961526, Actual 669
# Model: 813.8479731334028, Actual 911
# Model: 2208.490948739733, Actual 761
# Model: 5949.738091907132, Actual 6994
# Model: 5617.3870265117, Actual 9286
# Model: 4846.29841819554, Actual 6098
# Model: 1092.6786692151504, Actual 450
# Model: 3614.096832132525, Actual 3398
# Model: 3664.127741493292, Actual 3816
# Model: 520.9588576574151, Actual 743
# Model: 4184.319899317593, Actual 4284
# Model: 1091.553926327535, Actual 462
# Model: 5792.04983511948, Actual 7821
# Model: 3753.4831206712984, Actual 3746
# Model: 1317.7797513380665, Actual 1240
# Model: 652.8063486427832, Actual 666
# Model: 3427.628373099074, Actual 2683
# Model: 4499.72834206635, Actual 4899
# Model: 5983.761290065936, Actual 9158
# Model: 2376.0913781862923, Actual 2255
# Model: 6122.005037679913, Actual 7431
# Model: 4369.82589895932, Actual 5443
# Model: 4049.0049419529455, Actual 5460
# Model: 5532.167024279246, Actual 16231
# Model: 846.91809799051, Actual 873
# Model: 6346.847152545496, Actual 11206
# Model: 1192.1961109306721, Actual 1034
# Model: 718.087399202218, Actual 734
# Model: 4354.532465719243, Actual 4384
# Model: 5105.6575609184465, Actual 6552
# Model: 5361.69829855175, Actual 6559
# Model: 506.5596475064349, Actual 936
# Model: 5573.43084252357, Actual 7882
# Model: 2567.5992087778195, Actual 2458
# Model: 4738.965089362194, Actual 6745
# Model: 5442.0907430462, Actual 7611
# Model: 3532.1066420668817, Actual 2843
# Model: 6424.526868559856, Actual 8689
# Model: 2343.531827647214, Actual 3247
# Model: 4884.476777418841, Actual 4028
# Model: 668.1944037926346, Actual 861
# Model: 1601.739424602139, Actual 1786
# Model: 1720.089591834989, Actual 1724
# Model: 1132.0529627090077, Actual 506
# Model: 5400.3661418946185, Actual 6640
# Model: 2087.558374984481, Actual 1979
# Model: 591.3102771055374, Actual 791
# Model: 1468.3135568522155, Actual 663
# Model: 2439.1576286501254, Actual 2297
# Model: 3570.663390876194, Actual 3528
# Model: 4901.13521122895, Actual 4746
# Model: 1565.7676151028938, Actual 1155
# Model: 673.9273361347055, Actual 489
# Model: 1147.7132719699475, Actual 1069
# Model: 1542.3208111944273, Actual 1257
# Model: 5751.3807724914595, Actual 12853
# Model: 1723.8476920268029, Actual 1627
# Model: 1808.5571729789258, Actual 1767
# Model: 1243.9703112264542, Actual 1123
# Model: 6559.746615954406, Actual 7797
# Model: 639.7809310438861, Actual 702
# Model: 687.2644952383612, Actual 666
# Model: 716.9948144248847, Actual 700
# Model: 999.4050683699948, Actual 1073
# Model: 2735.1827864634975, Actual 2756
# Model: 1333.671154152002, Actual 452
# Model: 6863.046314353151, Actual 9920
# Model: 1756.1524670346364, Actual 1786
# Model: 732.2099340105824, Actual 810
# Model: 728.8541687037114, Actual 684
# Model: 5808.836859642122, Actual 6857
# Model: 5602.510814873342, Actual 10773
# Model: 3922.9925804611744, Actual 4002
# Model: 4323.306770583186, Actual 3725
# Model: 1239.5911817595493, Actual 1068
# Model: 5586.589427737137, Actual 4348
# Model: 3081.3933349086374, Actual 3464
# Model: 7623.301888574724, Actual 9551
# Model: 1328.1741113505768, Actual 674
# Model: 3133.7209516606295, Actual 2797
# Model: 4626.8564964095585, Actual 5287
# Model: 6967.075323432265, Actual 12798
# Model: 1205.0644943303687, Actual 1222
# Model: 5842.349526440894, Actual 7731
# Model: 4931.3183741092, Actual 4256
# Model: 3783.752065645899, Actual 3357
# Model: 3524.523252935459, Actual 4454
# Model: 709.2323954614772, Actual 678
# Model: 6926.3127092340965, Actual 9185
# Model: 2315.5212370077893, Actual 1799
# Model: 588.4958698384071, Actual 765
# Model: 884.9894370037341, Actual 1007
# Model: 6083.068091855852, Actual 15511
# Model: 2269.044215240184, Actual 1666
# Model: 3960.966219507136, Actual 4070
# Model: 5193.328088288507, Actual 17996
# Model: 7003.9233143720085, Actual 13607
# Model: 3426.729503878093, Actual 3240
# Model: 5213.632468798452, Actual 7934
# Model: 2594.2409001645074, Actual 2395
# Model: 2667.233518975664, Actual 1334
# Model: 1130.7177173626746, Actual 1050
# Model: 2694.976493664333, Actual 2612
# Model: 670.6505100589243, Actual 491
# Model: 4573.406990886589, Actual 4306
# Model: 1149.932357925717, Actual 979
# Model: 6171.752338322681, Actual 9817
# Model: 1900.291158686927, Actual 1723
# Model: 6038.1620899694535, Actual 18186
# Model: 4803.251016687016, Actual 8681
# Model: 737.5253698081174, Actual 432
# Model: 7367.396670693473, Actual 14247
# Model: 801.0901562541944, Actual 721
# Model: 1864.3202342235184, Actual 1092
# Model: 5762.34874430446, Actual 5273
# Model: 2754.743909053756, Actual 4025
# Model: 6902.840911306014, Actual 11957
# Model: 1415.6842875622026, Actual 1591
# Model: 728.4788353862523, Actual 755
# Model: 965.5744606396138, Actual 680
# Model: 598.0621429544826, Actual 666
# Model: 929.1905949023567, Actual 1138
# Model: 5048.182499219145, Actual 8162
# Model: 1267.4158974287875, Actual 957
# Model: 2329.992022502046, Actual 2395
# Model: 2602.5086399841302, Actual 2662
# Model: 1367.1268401318555, Actual 413
# Model: 981.518358617825, Actual 732
# Model: 5269.293243374692, Actual 6499
# Model: 700.5613488423937, Actual 854
# Model: 7028.523323542549, Actual 16636
# Model: 3868.2190764019333, Actual 4054
# Model: 696.8352591435396, Actual 798
# Model: 3055.168279116375, Actual 1770
# Model: 6052.555132883458, Actual 9705
# Model: 4407.923718692223, Actual 3678
# Model: 6038.1788484507015, Actual 14579

# %%
clf.score(X_test,y_test)
# Out:
# 0.5308120576056846
